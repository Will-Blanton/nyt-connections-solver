# %% [markdown]
# Author: Will Blanton

# %% [markdown]
# # Imports

# %%
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import random
import itertools

import torch_geometric
# from sentence_transformers import SentenceTransformer

from gensim.models.fasttext import load_facebook_vectors
from sklearn.feature_extraction.text import CountVectorizer
from torch.utils.data import Dataset
from torch.nn.functional import cosine_similarity
from torch_geometric.data import Data
from torch_geometric.loader import DataLoader
from torch_geometric.nn import knn_graph

# %% [markdown]
# # Helper Functions

# %%
def extract_features(word):
    return pd.DataFrame({word:{
        'length': len(word),
        'num_vowels': sum(c in 'aeiou' for c in word.lower()),
        'num_consonants': sum(c.isalpha() and c not in 'aeiou' for c in word.lower()),
        'ends_with_ing': int(word.lower().endswith('ing')),
        'ends_with_ed': int(word.lower().endswith('ed')),
        'is_palindrome': int(word.lower() == word[::-1].lower())
    }})

def extract_structural_features(words):
    """
    Extract basic structural features for the given words.
    """
    return torch.tensor(pd.concat([extract_features(w) for w in words], axis=1).T.values)

# %% [markdown]
# # Create Dataset

# %%
random.seed(0)
torch.manual_seed(0)

# %%
print(f"Cuda available: {torch.cuda.is_available()}")
# Out:
# Cuda available: True

# %%
# TODO: try prompt with sentence transformer
# word_embedder = SentenceTransformer('all-MiniLM-L6-v2')

# %%
ft = load_facebook_vectors('pretrained/cc.en.300.bin')

# %%
class FastTextEmbedder:
    """
    Wrap gensim embeddings for simpler conversion to tensors and to fit with sentence-transformers api for easy swapping
    """
    def __init__(self, ft_model):
        self.ft = ft_model
        self.dim = ft_model.vector_size

    def encode(self, word_list, convert_to_tensor=True):
        vectors = []
        for word in word_list:
            vectors.append(self.ft[word])

        vectors = np.stack(vectors)

        if convert_to_tensor:
            return torch.tensor(vectors, dtype=torch.float)
        else:
            return vectors

# %%
word_embedder = FastTextEmbedder(ft)

# %%
import ast
connections_df = pd.read_csv('data/connections.csv', index_col=0)
# connections_df.drop(columns='category', inplace=True)

# fix issues with incorrect format... (not worth going in and adding a mechanism to correct...)
connections_df.loc[1298, "connections"] = "['line', 'plane', 'point', 'solid']"
connections_df.loc[1892, "connections"] = "['abyss', 'fly', 'matrix', 'thing']"

# remove april fools samples since they include emojis or other potentially noisy samples
connections_df = connections_df[~connections_df['date'].str.contains("04-01")]
connections_df.reset_index(drop=True, inplace=True)

# connections_df['connections'] = connections_df['connections'].apply(ast.literal_eval)
connections_df
# Out:
#             date           category                             connections
# 0     2023-06-12        palindromes   ['kayak', 'level', 'mom', 'race car']
# 1     2023-06-12      keyboard keys    ['option', 'return', 'shift', 'tab']
# 2     2023-06-12          nba teams       ['bucks', 'heat', 'jazz', 'nets']
# 3     2023-06-12        wet weather       ['hail', 'rain', 'sleet', 'snow']
# 4     2023-06-13  letter homophones          ['are', 'queue', 'sea', 'why']
# ...          ...                ...                                     ...
# 2751  2025-05-01           winnings     ['pot', 'prize', 'purse', 'reward']
# 2752  2025-05-02            ___neck  ['bottle', 'break', 'goose', 'turtle']
# 2753  2025-05-02       bbq offering          ['dog', 'link', 'rib', 'wing']
# 2754  2025-05-02             pillar    ['brace', 'post', 'prop', 'support']
# 2755  2025-05-02  kinds of carvings   ['bust', 'relief', 'statue', 'torso']
#
# [2756 rows x 3 columns]

# %%
class ConnectionsData(Data):
    # needed to adjust the edge group indices for batching
    def __inc__(self, key, value, *args, **kwargs):
        if key == 'group_indices':
            # group_indices refers to node indices → so shift by number of nodes
            return self.x.size(0)
        else:
            return super().__inc__(key, value, *args, **kwargs)

# %%
all_words = list(set(itertools.chain.from_iterable(
    connections_df
    .groupby('date')['connections']
    .agg(lambda lists: list(itertools.chain.from_iterable(lists)))
    .values
)))
all_words
# Out:
# ['sugar',
#  'hank',
#  'cole',
#  'nature',
#  'hesitate',
#  'rim',
#  'golf club',
#  'font',
#  'punt',
#  'bikini',
#  'network',
#  'education',
#  'ferment',
#  'zoom',
#  'forecast',
#  'waver',
#  'beaker',
#  'jelly',
#  'oppenheimer',
#  'salad',
#  'sew',
#  'teeth',
#  'metaverse',
#  'rocker',
#  'mechanism',
#  'fashion',
#  'dope',
#  'clam',
#  'observe',
#  'natty',
#  'withs - brat',
#  'wing',
#  'pecan',
#  'screw',
#  'hover',
#  'odor',
#  'cement',
#  'bookend',
#  'sock',
#  'prune',
#  'refresh',
#  'manhattan',
#  'happy',
#  'target',
#  'rhyme',
#  'dollar',
#  'boil',
#  'tetherball',
#  'grab',
#  'cosmetic',
#  'supply',
#  'count',
#  'monkee',
#  'sham',
#  'grayscale',
#  'baggage',
#  'purr',
#  'delay',
#  'grandstand',
#  'goldilocks',
#  'well',
#  'ketchum',
#  'jitter',
#  'soon',
#  'winery',
#  'touch',
#  'burrito',
#  'penny',
#  'am',
#  'rugged',
#  'percent',
#  'location',
#  'radiant',
#  'cyclone',
#  'tennessee',
#  'kiln',
#  'maintain',
#  'ebb',
#  'doh',
#  'deck of cards',
#  'tartar',
#  'insurance',
#  'thingamajig',
#  'bungee',
#  'brook',
#  'bet',
#  'walk',
#  'cream',
#  'divine',
#  'of',
#  'trifle',
#  'live',
#  'cochlea',
#  'lab',
#  'me',
#  'whoop',
#  'knead',
#  'lid',
#  'quirky',
#  'flame',
#  'types',
#  'and-white things - crossword',
#  'postpone',
#  'quality',
#  'break',
#  '7',
#  'sit',
#  'crew',
#  'spell',
#  'apologies',
#  'album',
#  'venus de milo',
#  'mama',
#  'prisoner',
#  'war',
#  'liar',
#  'shape',
#  'thirst',
#  'text',
#  'sphynx',
#  'spirit',
#  'vase',
#  'understand',
#  'anger',
#  'spy',
#  'lp',
#  'katy perry',
#  'foster',
#  'diamonds',
#  'shave',
#  'ok',
#  'radish',
#  'pickings',
#  'mature',
#  'offs - best',
#  'kettle',
#  'nose',
#  'beetle',
#  'lift',
#  'wallet',
#  'showboat',
#  'special',
#  'council',
#  'florist',
#  'devil',
#  'jean',
#  'daffy',
#  'jiff',
#  'crimp',
#  'get',
#  'aquarium',
#  'coarse',
#  'wall',
#  'voltage',
#  'colon',
#  'coriander',
#  'pulse',
#  'rivet',
#  'wallace',
#  'lunch',
#  'dazzle',
#  'moving',
#  'robot',
#  'us',
#  'peek',
#  'forge',
#  'race car',
#  'asteroid',
#  'sesame',
#  'beetlejuice',
#  'commerce',
#  'boilerplate',
#  'puffing',
#  'friends',
#  'mack',
#  'evil',
#  'gravity',
#  'vertex',
#  'rings',
#  'drain',
#  'tulip',
#  'yo-yo',
#  'nuts',
#  'gallon',
#  'heavy',
#  'wits',
#  'dizzy',
#  'deny',
#  'silver medal',
#  'gingerbread',
#  'lemon',
#  'family',
#  'riot',
#  'surge',
#  'proceeding',
#  'memory',
#  'static',
#  'curve',
#  'skull',
#  'kinds',
#  'favor',
#  'element',
#  'lap',
#  'tire',
#  'kettles',
#  'snowglobe',
#  'domain',
#  'rudolph',
#  'mud',
#  'tramp',
#  'mogul',
#  'guts',
#  'tumbler',
#  'regal',
#  'ape',
#  'garish',
#  'thumb',
#  'writing',
#  'hog',
#  'statue of liberty',
#  'dragon',
#  'soap',
#  'on',
#  'taboo',
#  'flake',
#  'ancestry',
#  'laurel',
#  'declare',
#  'carmela',
#  'gander',
#  'nether',
#  'scoop',
#  'shield',
#  'here',
#  'dart',
#  'russian blue',
#  'pluto',
#  'rotate',
#  'goggle',
#  'cape',
#  'yard',
#  'contraction',
#  'bluff',
#  'hits',
#  'fund',
#  'expand',
#  'fishbowl',
#  'risque',
#  'brand',
#  'hammock',
#  'turkeys',
#  'roger',
#  'paisley',
#  'guinea pig',
#  'merrily',
#  'wishes',
#  'tube',
#  'crucifix',
#  'rich',
#  'sear',
#  't-square',
#  'goose',
#  'peels',
#  'stallion',
#  'cheek',
#  'deck',
#  'oat',
#  'canvas',
#  'cryptography',
#  'zest',
#  'massage',
#  'bent',
#  'specify',
#  'beam',
#  'to boot',
#  'skip',
#  'bogus',
#  'skillet',
#  'pitcher',
#  'cygnus',
#  'gnat',
#  'cuckoo',
#  'tasting',
#  'lance',
#  'radical',
#  'peal',
#  'flair',
#  'cheese',
#  'griffin',
#  'little',
#  'walrus',
#  'hairy',
#  'tease',
#  'aaron',
#  'fog',
#  'symphony',
#  'tourist',
#  'snob',
#  'holy',
#  'madonna',
#  'vision',
#  'phoenix',
#  'yankee',
#  'butte',
#  'bolt',
#  'guess',
#  'tiara',
#  'bong',
#  'caterpillar',
#  'tony',
#  'stall',
#  'fair',
#  'giraffe',
#  'thumbs up',
#  'naughty',
#  'everything',
#  'conveyor belt',
#  'eleventh',
#  'bloody',
#  'detective',
#  'sweetheart',
#  'files',
#  'collective',
#  'liver',
#  'gucci',
#  'garlic',
#  'gutter',
#  'democratic',
#  'from',
#  'birthday',
#  'shoe',
#  'grey',
#  'millennium',
#  'knocks',
#  'fulfill',
#  'bock',
#  'put away',
#  'gift',
#  'singular',
#  'host',
#  'electrical',
#  'dogs',
#  'tee (shirt)',
#  'lure',
#  'gov',
#  'nearby',
#  'fang',
#  'pretty',
#  'push-up',
#  'whine',
#  'active',
#  'glee',
#  'just',
#  'dogma',
#  'best boy',
#  'bamboo',
#  'mirth',
#  'impossible',
#  'kisser',
#  'prairie',
#  'carte',
#  'grande',
#  'mona lisa',
#  'zag',
#  'ultra',
#  'brick',
#  'able',
#  'python',
#  'giveaway',
#  'have',
#  'biped',
#  'gag',
#  'diablo',
#  'peeler',
#  'spider',
#  'too',
#  'roller coaster',
#  'eel',
#  'fox',
#  'back',
#  'doge',
#  'graduate',
#  'photoshop',
#  'gram',
#  'times',
#  'lessen',
#  'glue',
#  'regard',
#  'type',
#  'stock',
#  'mayo',
#  'heath',
#  'nike',
#  'quarrel',
#  'reading',
#  'adhere',
#  'nat',
#  'ken',
#  'tone',
#  'holly',
#  'fuzzy',
#  'trunk',
#  'bud',
#  'crouch',
#  'divider',
#  'empty',
#  'oreo',
#  'hood',
#  'hem',
#  'beret',
#  'sally',
#  'must',
#  'samurai',
#  'cooking',
#  'hearty',
#  'marvel',
#  'scale',
#  'killer',
#  'nemo',
#  'napkin',
#  'blast',
#  'burst',
#  'ground',
#  'dna',
#  'singer',
#  'intro class',
#  'magic',
#  'fret',
#  'york',
#  'horns',
#  'accord',
#  'nag',
#  'cotton ball',
#  'taylor',
#  'china',
#  'boo',
#  'creak',
#  'towel',
#  'koko',
#  'sully',
#  'retro',
#  'secure',
#  'finale',
#  'pisa',
#  'carter',
#  'sling',
#  'soda can',
#  'gin',
#  'mountain climber',
#  'gee',
#  'fence',
#  'haired animals - afghan',
#  'ironic',
#  'glow',
#  'dolly',
#  'better',
#  'sculpture',
#  'nonsense',
#  'sweetie',
#  'exclamation points',
#  'egg',
#  'beethoven',
#  'cover',
#  'tray',
#  'bull',
#  'tough',
#  'chest',
#  'jab',
#  'pumpkin',
#  'tend',
#  'media',
#  'get well',
#  'feelings',
#  'tutu',
#  'page',
#  'expansive',
#  'leech',
#  'frasier',
#  'tech',
#  'alfa',
#  'poetry',
#  'astroturf',
#  'moo',
#  'seize',
#  'come',
#  'o',
#  'phone',
#  'folly',
#  'glimpse',
#  'happiness',
#  'mar',
#  'chunky',
#  'tinge',
#  'lime',
#  'bell',
#  'grip',
#  'fey',
#  'eventually',
#  'sneaker',
#  'room',
#  'bowling',
#  'civilization',
#  'boo-boo',
#  'mod',
#  'brake',
#  'bath',
#  'loot',
#  'suggest',
#  'bonobo',
#  'app',
#  'hand',
#  'digs',
#  'period',
#  'cluster',
#  'ankh',
#  'blaze',
#  'twist',
#  'mess',
#  'fisher',
#  'hug',
#  'extra',
#  'saint',
#  'inhibit',
#  'definition',
#  'cash',
#  'bicycle',
#  'grand',
#  'peanuts',
#  'caveat',
#  'horse',
#  'domino',
#  'tenet',
#  'phony',
#  'floor',
#  'smear',
#  'outline',
#  'draw',
#  'mallet',
#  'neutral',
#  'reel',
#  'trap',
#  'flames',
#  'billboard',
#  'banks',
#  'ice',
#  'pads',
#  'express',
#  'shy',
#  'place',
#  'chapter',
#  'world',
#  'planet',
#  'volt',
#  'toes',
#  'pleats',
#  'button',
#  'cash way to pay - card',
#  'nibble',
#  'visible',
#  'silicon',
#  'steps',
#  'at',
#  'styles',
#  'monk',
#  'jostle',
#  'clark',
#  'sack',
#  'intercoms',
#  'a bell',
#  'packing',
#  'funding',
#  'kid',
#  'goldfish',
#  'pink',
#  'seashells',
#  'hairpin',
#  'mine',
#  'ronald',
#  'eggs',
#  'promote',
#  'peat',
#  'dim',
#  'tidbit',
#  'stare',
#  'howser',
#  'wan',
#  'point',
#  'slow',
#  'stray',
#  'preserve',
#  'colorado',
#  'stiff',
#  'racks',
#  'approved',
#  'do',
#  'sec',
#  'snug',
#  'murphy',
#  'viola',
#  'news',
#  'glide',
#  'yacht',
#  'meet',
#  'browser',
#  'radiolab',
#  'boiling',
#  'green light',
#  'props',
#  'madden',
#  'thump',
#  'rosebud',
#  'scrap',
#  'beyond',
#  'candidate',
#  'protest',
#  'myself',
#  'bury',
#  'flock',
#  'latin',
#  'flounder',
#  'venetian',
#  'cappuccino',
#  'common',
#  'narwhal',
#  'suede',
#  'smooth',
#  'chad',
#  'mc',
#  'corn',
#  'agent',
#  'tape',
#  'faze',
#  'but',
#  'capital',
#  'era',
#  'throb',
#  'james',
#  'photo',
#  'minefield',
#  'navy',
#  'mice',
#  'jerk',
#  'girl',
#  'caesar',
#  'remote',
#  'secrets',
#  'reputation',
#  'freight',
#  'driver',
#  'nonstop',
#  'manatee',
#  'mellon',
#  'santa',
#  'go',
#  'merry-go-round',
#  'heel',
#  'learn',
#  'chuck',
#  'maps',
#  'cedar',
#  'gaga',
#  'steaming',
#  'cell',
#  'junk',
#  'cactus',
#  'pool',
#  'obscure',
#  'kim',
#  'cold',
#  'manage',
#  'pizza',
#  'javelin',
#  'gum',
#  'scarecrow',
#  'oops',
#  'workshop',
#  'weave',
#  'psych',
#  'see-saw',
#  'civic',
#  'breakout',
#  'realize',
#  'couch',
#  'monticello',
#  'maraca',
#  'purple',
#  'faster',
#  'sound',
#  'discard',
#  'faith',
#  'we',
#  'feud',
#  'willy',
#  'aim',
#  'greek',
#  'operate',
#  'turncoat',
#  'proposal',
#  'mingle',
#  'fuji',
#  'guild',
#  'taste',
#  'snake',
#  'get out',
#  'mown',
#  'buff',
#  'listen',
#  'perk',
#  'boomer',
#  'baby powder',
#  'split',
#  'plywood',
#  'folio',
#  'maroon',
#  'publicity',
#  'tidal',
#  'vitamin',
#  'cars',
#  'quantity',
#  'bmw',
#  'badgers',
#  'utensils',
#  'zip',
#  'ala',
#  'cabaret',
#  'natural',
#  'healthy',
#  'muddle',
#  'wail',
#  'same',
#  'partridge',
#  'calculus',
#  'supper',
#  'noise',
#  'moan',
#  'eggnog',
#  'spike lee',
#  'wolverine',
#  'madison',
#  'ratched',
#  'swimmers',
#  'excuse',
#  'peppermint patty',
#  'meatball',
#  'mullet',
#  'easy',
#  'stroke',
#  'ad',
#  'queue',
#  'information',
#  'muzzle',
#  'hannah',
#  'cheerio',
#  'butty',
#  'sum',
#  'round',
#  'steady',
#  'barrier',
#  'caw',
#  'hurry',
#  'lion',
#  'espresso',
#  'pico',
#  'solution',
#  'guess who',
#  'seed',
#  'undo',
#  'pinch',
#  'wicked',
#  'exploratory',
#  'marx',
#  'hotshot',
#  'croissant',
#  'bake',
#  'frontline',
#  'hard',
#  'wand',
#  'vault',
#  'mash',
#  'scream',
#  'elementary',
#  'mary jane',
#  'lagos',
#  'kitchen',
#  'taxi driver',
#  'could',
#  'banana peel',
#  'dale',
#  'comics',
#  'dylan',
#  'inland',
#  'spontaneity',
#  'critical',
#  'structure',
#  'hint',
#  'whac-a-mole',
#  'launchpad',
#  'harvard',
#  'martian',
#  'skim',
#  'sodium',
#  'collection',
#  'witchcraft',
#  'engross',
#  'woodchuck',
#  'no',
#  'amy',
#  'cd',
#  'er',
#  'crop',
#  'organism',
#  'e',
#  'buggy',
#  'fin',
#  'built',
#  'chatter',
#  'friend',
#  'spin',
#  'dome',
#  'look',
#  'sleek',
#  'crumple',
#  'cheat',
#  'serve',
#  'spreadsheet',
#  'ski',
#  'soup',
#  'vacation',
#  'screwdriver',
#  'julienne',
#  'scott',
#  'far',
#  'tower',
#  '___ - boo',
#  'witness',
#  'suit',
#  'lice',
#  'section',
#  'relax',
#  'mario',
#  'satisfaction',
#  'william',
#  'license',
#  'blanket',
#  'ship',
#  'beer',
#  'backbone',
#  'tart',
#  'sleigh',
#  'ditch',
#  'ion',
#  'exposure',
#  'goodness',
#  'bassinet',
#  'vogue',
#  'listening',
#  'sword',
#  'elastic',
#  'typewriter',
#  'mole rat',
#  'crock',
#  'dole',
#  'fluke',
#  'pronounced',
#  'heard',
#  'carat',
#  'cornucopia',
#  'trapeze',
#  'backgammon',
#  'rollers',
#  'maze',
#  'tailgate',
#  'hourglass',
#  'homeroom',
#  'worm',
#  'crag',
#  'stop sign',
#  'benefit',
#  'malta',
#  'meal',
#  '___ - bone',
#  'creation',
#  'jackknife',
#  'smarter',
#  'trilogy',
#  'pug',
#  'expert',
#  'clout',
#  'boxer',
#  'voiced',
#  'mushroom',
#  'pluck',
#  'weeds',
#  'create',
#  'alternative',
#  'discount',
#  'pride',
#  'great',
#  'steam',
#  'reach',
#  'wood',
#  'box',
#  'works',
#  'semblance',
#  'galaxy',
#  'minute',
#  '40',
#  'lyme',
#  'dimensional objects - ball',
#  'won',
#  'canadien',
#  'ambient',
#  'clutch',
#  'hole',
#  'turtle',
#  'invite',
#  'sine',
#  'reward',
#  'nothing',
#  'data',
#  'village',
#  'pdf',
#  'irving',
#  'bowie',
#  'unforgettable',
#  'assignment',
#  'bask',
#  'axe',
#  'took in',
#  'resolution',
#  'bowtie',
#  'odd',
#  'loose',
#  'hydrant',
#  'impression',
#  'token',
#  'pint',
#  'vice',
#  'trick',
#  'area',
#  'tag',
#  'annie',
#  'pollen',
#  'chock',
#  'owl',
#  'mini',
#  'shelter',
#  'stencil',
#  'mug',
#  'sylvester',
#  'noodle',
#  'blush',
#  'shower',
#  'diss',
#  'wheels',
#  'tours',
#  'scepter',
#  'smack',
#  'hanger',
#  'croquet',
#  'throw',
#  'pane',
#  'dough',
#  'vibrate',
#  'ate',
#  'commando',
#  'horn',
#  'numbers',
#  'dumbbell',
#  'liberty bell',
#  'bugs',
#  'desert',
#  '___ - ball',
#  'outlet',
#  'nags',
#  'index',
#  'hoda',
#  'peer',
#  'carnation',
#  'spokes',
#  'dips',
#  'ozone',
#  'ding',
#  'win',
#  'believe',
#  'troll',
#  'tier',
#  'cornerstone',
#  'frontier',
#  'fish tank',
#  'courage',
#  'muscle',
#  'cool',
#  'gnocchi',
#  'knock',
#  'sharon',
#  'bag',
#  'orchestra',
#  'locker',
#  'airs',
#  ...]

# %%
[w for w in all_words if ('_' in w) or ('-' in w)]
# Out:
# ['withs - brat',
#  'and-white things - crossword',
#  'offs - best',
#  'yo-yo',
#  't-square',
#  'push-up',
#  'haired animals - afghan',
#  'boo-boo',
#  'cash way to pay - card',
#  'merry-go-round',
#  'see-saw',
#  'whac-a-mole',
#  '___ - boo',
#  '___ - bone',
#  'dimensional objects - ball',
#  '___ - ball',
#  'making verbs - garnish',
#  'o - daddy',
#  'name - designer',
#  'winning actors - bridges',
#  'six-pack',
#  'digit numbers - cannabis',
#  'up signs - applause',
#  'high-end',
#  'doo-wop',
#  'pop-up',
#  'modifying words - gothic',
#  'flip-flop',
#  't-bone',
#  'related - bookmark',
#  'the-moment - big',
#  'shaped food - bagel',
#  '___ - list',
#  'based airlines - american',
#  're-mi” - doe',
#  'shaped things - banana',
#  'walkie-talkie',
#  'white shades - cream',
#  'dyeing a shirt - basin',
#  'shaped container - cask',
#  'cracy - auto',
#  'topic remarks - aside',
#  'shangri-la',
#  'tilt-a-whirl',
#  'smelling - foul',
#  'go-go',
#  '” - angle',
#  'ending phrase - going',
#  '___ - clef',
#  'giving accessories - bow',
#  'timer - great',
#  'fashioned - square',
#  'and-white animals - orca',
#  'fried food - falafel',
#  'related jumbles - hash',
#  'go-ahead',
#  'ball-in-cup',
#  'vampire - crucifix',
#  'fitting - clingy',
#  'dimensional shapes - circle',
#  'x-ray',
#  'and foot-related slang - digit',
#  'q-tip',
#  'ism - expression',
#  '” - chip',
#  'thigh-high',
#  'bumper-to-bumper',
#  'thumbs-up',
#  'ad-lib',
#  'offs - always',
#  'teeter-totter',
#  'david-and-goliath',
#  'stand-up',
#  'shaped things - bagel',
#  'related - dinosaur',
#  'related - mistletoe',
#  'ough” words that don’t rhyme - bough',
#  'a-f',
#  'songwriter pianists - keys',
#  'ding-dong',
#  'd shapes - cone',
#  'shaped - bouillon',
#  'g-string',
#  'down calculator - boob',
#  'so-so',
#  '” things - cigarette',
#  'sounding names - cheers',
#  'moving water - cascade',
#  'time great - best',
#  'rags-to-riches',
#  'ups in super mario world - feather',
#  'spirit of christmas - bah',
#  'har-har',
#  'from-behind stories - cinderella',
#  'shaped things - can',
#  'brown shades - beige',
#  'size" to mean small - bite',
#  'ons - addition',
#  'or left-handed - baseball glove',
#  'fi franchises - alien',
#  'knock-knock',
#  'bo- compound words - tollbooth']

# %%
vectorizer = CountVectorizer(analyzer='char', ngram_range=(1, 4))
vectorizer.fit(all_words)

# %%
"""

TODO: add more features to handle complicated cases
- phonetic word embeddings
- character-level embeddings (either trained via RNN or pre-trained)
- n-gram?
"""
class ConnectionsGraphDataset(Dataset):
    def __init__(
        self,
        puzzle_df: pd.DataFrame,
        word_emb_model,
        char_vectorizer,
        k=8,
        negative_ratio: int = 3,
        include_purple: bool = False
    ):
        super().__init__()
        self.puzzle_df = puzzle_df
        self.negative_ratio = negative_ratio
        self.k = k
        self.include_purple = include_purple
        self.data_list = []

        # get lists of words for each puzzle 
        words_per_date = (
            self.puzzle_df
            .groupby('date')['connections']
            .agg(lambda lists: list(itertools.chain.from_iterable(lists)))
        )

        # create data object for each puzzle
        for date, word_list in words_per_date.items():
            if len(word_list) != 16:
                raise ValueError(f'Word list length {len(word_list)} does not match 16 words')
            data = self._build_single_graph(date, word_list, word_emb_model, char_vectorizer)
            self.data_list.append(data)

    def _build_single_graph(self, date, word_list, word_emb_model, char_vectorizer):
        
        # create node features 
        x = word_emb_model.encode(word_list, convert_to_tensor=True)
        word2idx = {w: i for i, w in enumerate(word_list)}

        edge_index, edge_attr = self._make_graph(x)

        positives = self._collect_positives(date, word2idx)
        negatives = self._sample_negatives(len(word_list), positives)

        # remove purple pairs (already handled for negatives)
        if not self.include_purple:
            positives = positives[:-3]

        group_indices = torch.tensor(positives + negatives, dtype=torch.long)
        group_labels = torch.tensor(
            [1]*len(positives) + [0]*len(negatives),
            dtype=torch.float
        )

        data = ConnectionsData(
            x=x,    # (16, embed_dim)
            x_char=torch.tensor(char_vectorizer.fit_transform(word_list).toarray()),
            x_struct=extract_structural_features(word_list),
            edge_index=edge_index,  # (2, num_edges)
            edge_attr=edge_attr, # (num_edges, 1)
            group_indices=group_indices,  # (num_groups, 4)
            group_labels=group_labels     # (num_groups,)
        )

        data.word_list = word_list
        return data

    def _make_graph(self, x):
        """
        Construct KNN graph for words
        :param x: 
        :param k: 
        :return: 
        """
        
        x = x.to("cuda" if torch.cuda.is_available() else "cpu")
        edge_index = knn_graph(x, k=self.k, batch=None, loop=False, cosine=True)
        x = x.cpu()
        edge_index = edge_index.cpu()

        # leave as directed since knn relationship is asymmetrical 
        # edge_index = to_undirected(edge_index)

        # edge attributes (cosine similarity)
        src = x[edge_index[0]]
        dst = x[edge_index[1]]
        edge_attr = cosine_similarity(src, dst).unsqueeze(1)

        return edge_index, edge_attr

    def _collect_positives(self, date, word2idx):
        subset = self.puzzle_df[self.puzzle_df['date'] == date]
        positives = []
        for _, row in subset.iterrows():
            idxs = [word2idx[w] for w in row['connections']]
            positives.append(sorted(idxs))
        return positives

    def _sample_negatives(self, num_nodes, positives):
        positive_set = set(tuple(g) for g in positives)
        all_quads = list(itertools.combinations(range(num_nodes), 4))
        random.shuffle(all_quads)

        negatives = []

        if self.include_purple: 
            max_neg = self.negative_ratio * len(positives)
        else:
            max_neg = self.negative_ratio * (len(positives) - 3)
        
        for quad in all_quads:
            if len(negatives) >= max_neg:
                break
            if tuple(quad) not in positive_set:
                negatives.append(list(quad))
        return negatives

    def __len__(self):
        return len(self.data_list)

    def __getitem__(self, idx):
        return self.data_list[idx]

# %%
# split data
dates = connections_df["date"].unique()
train_idx = random.sample(range(len(dates)), k=int(len(dates) * .8))
train_dates = dates[train_idx]
test_dates = dates[~np.isin(range(len(dates)), train_idx)]

test_dates = np.random.permutation(test_dates)
split_idx = len(test_dates) // 2
val_dates = test_dates[split_idx:]
test_dates = test_dates[:split_idx]

print(f"Total Length: {len(dates)}")
print(f"Train length: {len(train_dates)}")
print(f"Val length: {len(val_dates)}")
print(f"Test length: {len(test_dates)}")
# Out:
# Total Length: 689
# Train length: 551
# Val length: 69
# Test length: 69

# %%
BATCH_SIZE = 8
NEGATIVE_RATIO = 3
INCLUDE_PURPLE = False

train = ConnectionsGraphDataset(connections_df.loc[connections_df["date"].isin(train_dates)], word_embedder, vectorizer, negative_ratio=NEGATIVE_RATIO, include_purple=INCLUDE_PURPLE)
train_loader = DataLoader(train, batch_size=BATCH_SIZE, shuffle=True)

val = ConnectionsGraphDataset(connections_df.loc[connections_df["date"].isin(val_dates)], word_embedder, vectorizer, negative_ratio=NEGATIVE_RATIO, include_purple=INCLUDE_PURPLE)
val_loader = DataLoader(val, batch_size=BATCH_SIZE, shuffle=True)

test = ConnectionsGraphDataset(connections_df.loc[connections_df["date"].isin(test_dates)], word_embedder, vectorizer, negative_ratio=NEGATIVE_RATIO, include_purple=INCLUDE_PURPLE)
test_loader = DataLoader(test, batch_size=BATCH_SIZE, shuffle=True)

# %%
del word_embedder
del ft

# %%
# NUM_SAMPLES = (4 if INCLUDE_PURPLE else 3) * (NEGATIVE_RATIO + 1)

# %%
for batch in DataLoader(val, batch_size=2, shuffle=True):
    print(batch)
    print(batch.group_indices)

    x = batch.x
    group_embeds = x[batch.group_indices]
    print(group_embeds.view(group_embeds.size(0), -1).shape)
    
    break
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 for batch in DataLoader(val, batch_size=2, shuffle=True):
#       2     print(batch)
#       3     print(batch.group_indices)
#
# File D:\PyCharmProjects\nyt-connections-solver\.venv\Lib\site-packages\torch\utils\data\dataloader.py:708, in _BaseDataLoaderIter.__next__(self)
#     705 if self._sampler_iter is None:
#     706     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     707     self._reset()  # type: ignore[call-arg]
# --> 708 data = self._next_data()
#     709 self._num_yielded += 1
#     710 if (
#     711     self._dataset_kind == _DatasetKind.Iterable
#     712     and self._IterableDataset_len_called is not None
#     713     and self._num_yielded > self._IterableDataset_len_called
#     714 ):
#
# File D:\PyCharmProjects\nyt-connections-solver\.venv\Lib\site-packages\torch\utils\data\dataloader.py:764, in _SingleProcessDataLoaderIter._next_data(self)
#     762 def _next_data(self):
#     763     index = self._next_index()  # may raise StopIteration
# --> 764     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     765     if self._pin_memory:
#     766         data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# File D:\PyCharmProjects\nyt-connections-solver\.venv\Lib\site-packages\torch\utils\data\_utils\fetch.py:55, in _MapDatasetFetcher.fetch(self, possibly_batched_index)
#      53 else:
#      54     data = self.dataset[possibly_batched_index]
# ---> 55 return self.collate_fn(data)
#
# File D:\PyCharmProjects\nyt-connections-solver\.venv\Lib\site-packages\torch_geometric\loader\dataloader.py:27, in Collater.__call__(self, batch)
#      25 elem = batch[0]
#      26 if isinstance(elem, BaseData):
# ---> 27     return Batch.from_data_list(
#      28         batch,
#      29         follow_batch=self.follow_batch,
#      30         exclude_keys=self.exclude_keys,
#      31     )
#      32 elif isinstance(elem, torch.Tensor):
#      33     return default_collate(batch)
#
# File D:\PyCharmProjects\nyt-connections-solver\.venv\Lib\site-packages\torch_geometric\data\batch.py:97, in Batch.from_data_list(cls, data_list, follow_batch, exclude_keys)
#      82 @classmethod
#      83 def from_data_list(
#      84     cls,
#    (...)     87     exclude_keys: Optional[List[str]] = None,
#      88 ) -> Self:
#      89     r"""Constructs a :class:`~torch_geometric.data.Batch` object from a
#      90     list of :class:`~torch_geometric.data.Data` or
#      91     :class:`~torch_geometric.data.HeteroData` objects.
#    (...)     95     Will exclude any keys given in :obj:`exclude_keys`.
#      96     """
# ---> 97     batch, slice_dict, inc_dict = collate(
#      98         cls,
#      99         data_list=data_list,
#     100         increment=True,
#     101         add_batch=not isinstance(data_list[0], Batch),
#     102         follow_batch=follow_batch,
#     103         exclude_keys=exclude_keys,
#     104     )
#     106     batch._num_graphs = len(data_list)  # type: ignore
#     107     batch._slice_dict = slice_dict  # type: ignore
#
# File D:\PyCharmProjects\nyt-connections-solver\.venv\Lib\site-packages\torch_geometric\data\collate.py:109, in collate(cls, data_list, increment, add_batch, follow_batch, exclude_keys)
#     106     continue
#     108 # Collate attributes into a unified representation:
# --> 109 value, slices, incs = _collate(attr, values, data_list, stores,
#     110                                increment)
#     112 # If parts of the data are already on GPU, make sure that auxiliary
#     113 # data like `batch` or `ptr` are also created on GPU:
#     114 if isinstance(value, Tensor) and value.is_cuda:
#
# File D:\PyCharmProjects\nyt-connections-solver\.venv\Lib\site-packages\torch_geometric\data\collate.py:205, in _collate(key, values, data_list, stores, increment)
#     202         shape[cat_dim] = int(slices[-1])
#     203     out = elem.new(storage).resize_(*shape)
# --> 205 value = torch.cat(values, dim=cat_dim or 0, out=out)
#     207 if increment and isinstance(value, Index) and values[0].is_sorted:
#     208     # Check whether the whole `Index` is sorted:
#     209     if (value.diff() >= 0).all():
#
# RuntimeError: Sizes of tensors must match except in dimension 0. Expected size 181 but got size 174 for tensor number 1 in the list.

# %% [markdown]
# # Model Architecture

# %%
from torch_geometric.nn import GATv2Conv

class GraphEncoderLayer(nn.Module):
    def __init__(self, hidden_dim, local_heads, global_heads, dropout, edge_dim):
        super().__init__()
        
        self.local_conv = GATv2Conv(
            in_channels=hidden_dim,
            out_channels=hidden_dim,
            heads=local_heads,
            edge_dim=edge_dim,
            dropout=dropout,
            concat=False
        )
        
        self.global_attn = nn.MultiheadAttention(
            embed_dim=hidden_dim,
            num_heads=global_heads,
            dropout=dropout,
            batch_first=True
        )
        
        # Dropout + LayerNorm
        self.dropout = nn.Dropout(dropout)
        self.norm = nn.LayerNorm(hidden_dim)

    def forward(self, x, edge_index, edge_attr):
        residual = x

        x = self.local_conv(x, edge_index, edge_attr)

        x = x.unsqueeze(0)
        x, _ = self.global_attn(x, x, x)
        x = x.squeeze(0)

        x = self.dropout(x)
        x = self.norm(x + residual)

        return x

# %%
# TODO: implement an auto-regressive variant that builds groups instead of validating groups
class ConnectionsGNN(torch.nn.Module):
    def __init__(
            self,
            in_dim,
            num_layers=1,
            hidden_size=256,
            output_size=1,
            attn_heads=8,
            agg_heads=2,
            dropout=0.2,
            edge_dim=1
        ):
        super().__init__()

        self.lin_proj = nn.Linear(in_dim, hidden_size)
        
        self.layers = torch.nn.ModuleList()
        
        for i in range(num_layers):
            local_heads = attn_heads[i] if isinstance(attn_heads, list) else attn_heads
            self.layers.append(GraphEncoderLayer(hidden_size, local_heads, 2, dropout + .3, edge_dim))

        # batch_first so dim 1 is considered as the sequence (even though technically not a batch)
        self.attn_agg = nn.MultiheadAttention(hidden_size, agg_heads, dropout=dropout, batch_first=True)
            
        self.out = nn.Sequential(
            nn.Linear(hidden_size, hidden_size // 2),
            nn.LayerNorm(hidden_size // 2),
            nn.ReLU(),
            nn.Dropout(dropout),

            nn.Linear(hidden_size // 2, hidden_size // 4),
            nn.LayerNorm(hidden_size // 4),
            nn.ReLU(),
            nn.Dropout(dropout),

            nn.Linear(hidden_size // 4, output_size)
        )

        
    def forward(self, x, edge_index, edge_attr, group_indices):
        
        x = self.lin_proj(x)    # (num_nodes, in_dim) -> (num_nodes, hidden_dim)

        # compute graph embeddings 
        for layer in self.layers:
            x = layer(x, edge_index, edge_attr) # (num_nodes, hidden_dim)
            
        # aggregate groups for final scores
        group_embs = x[group_indices]   # (num_groups, 4, hidden_dim)
        group_embs, _ = self.attn_agg(group_embs, group_embs, group_embs)   # (num_groups, 4, hidden_dim)
        group_embs, _ = group_embs.max(dim=1)   # (num_groups, hidden_dim)
        
        logits = self.out(group_embs)    # (num_groups, 1)
        return logits.squeeze(-1)   # (num_groups,)

# %% [markdown]
# # Train Model

# %%
from sklearn.metrics import roc_auc_score

def compute_auc(logits, labels):
    """
    logits: (batch_size,) torch.Tensor (raw logits)
    labels: (batch_size,) torch.Tensor (binary labels)
    """

    # Apply sigmoid to get probabilities
    probs = torch.sigmoid(logits)

    # Move to CPU and numpy
    probs = probs.detach().cpu().numpy()
    labels = labels.detach().cpu().numpy()

    # Compute ROC AUC
    auc = roc_auc_score(labels, probs)

    return auc

# %%
def evaluate(model, loader, loss_fn, device):
    model.eval()
    
    total_loss = 0
    all_logits = []
    all_labels = []
    
    with torch.no_grad():
        for batch in loader:
            x = batch.x.to(device)
            edge_index = batch.edge_index.to(device)
            edge_attr = batch.edge_attr.to(device)
            group_indices = batch.group_indices.to(device)
            y = batch.group_labels.to(device)

            logits = model(x, edge_index, edge_attr, group_indices)

            # Loss (BCEWithLogits → already mean over batch)
            batch_loss = loss_fn(logits, y)
            total_loss += batch_loss.item()

            # Store for AUC
            all_logits.append(logits.detach().cpu())
            all_labels.append(y.detach().cpu())

    # Compute average loss
    avg_loss = total_loss / len(loader)

    # Compute AUC → concatenate everything
    all_logits = torch.cat(all_logits)
    all_labels = torch.cat(all_labels)

    probs = torch.sigmoid(all_logits).numpy()
    labels = all_labels.numpy()

    auc = roc_auc_score(labels, probs)

    return avg_loss, auc

# %%
from tensorboardX import SummaryWriter

writer = SummaryWriter(log_dir="runs/connections_experiment")

EPOCHS = 500

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

model = ConnectionsGNN(
    in_dim=300,
    num_layers=2,
    hidden_size=1024,
    output_size=1,
    attn_heads=[4, 2],
    agg_heads=2,
    dropout=0.2,
    edge_dim=1 
).to(device)

optimizer = torch.optim.Adam(model.parameters(), lr=5e-3, weight_decay=1e-5)
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, 'min', patience=5)

loss = nn.BCEWithLogitsLoss()

for epoch in range(EPOCHS):
    model.train()
    train_loss = 0

    for batch in train_loader:
        x = batch.x.to(device)
        edge_index = batch.edge_index.to(device)
        edge_attr = batch.edge_attr.to(device)
        group_indices = batch.group_indices.to(device)
        y = batch.group_labels.to(device)

        logits = model(x, edge_index, edge_attr, group_indices)

        batch_loss = loss(logits, y)
        train_loss += batch_loss.item()

        optimizer.zero_grad()
        batch_loss.backward()
        optimizer.step()

    train_loss /= len(train_loader)

    val_loss, val_auc = evaluate(model, val_loader, loss, device)
    test_loss, test_auc = evaluate(model, test_loader, loss, device)

    scheduler.step(val_loss)

    if epoch % 10 == 0:
        # --- Tensorboard logging ---
        writer.add_scalar("loss/train", train_loss, epoch)
        writer.add_scalar("loss/val", val_loss, epoch)
        writer.add_scalar("loss/test", test_loss, epoch)

        writer.add_scalar("auc/val", val_auc, epoch)
        writer.add_scalar("auc/test", test_auc, epoch)

        current_lr = optimizer.param_groups[0]['lr']
        writer.add_scalar("lr", current_lr, epoch)

        for name, param in model.named_parameters():
            writer.add_histogram(f"param_hist/{name}", param, epoch)

            if param.grad is not None:
                writer.add_histogram(f"grad_hist/{name}", param.grad, epoch)

        print(f"Epoch {epoch} | Train Loss: {train_loss:.4f} | Val Loss: {val_loss:.4f} | Val AUC: {val_auc:.4f} | Test Loss: {test_loss:.4f} | Test AUC: {test_auc:.4f}")
# Out:
# Epoch 0 | Train Loss: 0.5789 | Val Loss: 0.5653 | Val AUC: 0.5011 | Test Loss: 0.5652 | Test AUC: 0.5012
# Epoch 10 | Train Loss: 0.5665 | Val Loss: 0.5625 | Val AUC: 0.4990 | Test Loss: 0.5625 | Test AUC: 0.5004
# Epoch 20 | Train Loss: 0.5639 | Val Loss: 0.5624 | Val AUC: 0.5036 | Test Loss: 0.5624 | Test AUC: 0.5067
# Epoch 30 | Train Loss: 0.5631 | Val Loss: 0.5624 | Val AUC: 0.5110 | Test Loss: 0.5624 | Test AUC: 0.4875
# Epoch 40 | Train Loss: 0.5617 | Val Loss: 0.5624 | Val AUC: 0.4943 | Test Loss: 0.5624 | Test AUC: 0.4926
# Epoch 50 | Train Loss: 0.5624 | Val Loss: 0.5624 | Val AUC: 0.4943 | Test Loss: 0.5624 | Test AUC: 0.4975
# Epoch 60 | Train Loss: 0.5626 | Val Loss: 0.5624 | Val AUC: 0.4975 | Test Loss: 0.5624 | Test AUC: 0.4911
# Epoch 70 | Train Loss: 0.5636 | Val Loss: 0.5624 | Val AUC: 0.4943 | Test Loss: 0.5624 | Test AUC: 0.5028
# Epoch 80 | Train Loss: 0.5631 | Val Loss: 0.5624 | Val AUC: 0.5074 | Test Loss: 0.5624 | Test AUC: 0.4817
# Epoch 90 | Train Loss: 0.5633 | Val Loss: 0.5624 | Val AUC: 0.4948 | Test Loss: 0.5624 | Test AUC: 0.4645
# Epoch 100 | Train Loss: 0.5634 | Val Loss: 0.5624 | Val AUC: 0.4955 | Test Loss: 0.5624 | Test AUC: 0.4976
# Epoch 110 | Train Loss: 0.5650 | Val Loss: 0.5624 | Val AUC: 0.5232 | Test Loss: 0.5625 | Test AUC: 0.5063
# Epoch 120 | Train Loss: 0.5630 | Val Loss: 0.5624 | Val AUC: 0.5009 | Test Loss: 0.5624 | Test AUC: 0.4851
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[21], line 36
#      33 group_indices = batch.group_indices.to(device)
#      34 y = batch.group_labels.to(device)
# ---> 36 logits = model(x, edge_index, edge_attr, group_indices)
#      38 batch_loss = loss(logits, y)
#      39 train_loss += batch_loss.item()
#
# File D:\PyCharmProjects\nyt-connections-solver\.venv\Lib\site-packages\torch\nn\modules\module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File D:\PyCharmProjects\nyt-connections-solver\.venv\Lib\site-packages\torch\nn\modules\module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# Cell In[17], line 48, in ConnectionsGNN.forward(self, x, edge_index, edge_attr, group_indices)
#      46 # compute graph embeddings
#      47 for layer in self.layers:
# ---> 48     x = layer(x, edge_index, edge_attr) # (num_nodes, hidden_dim)
#      50 # aggregate groups for final scores
#      51 group_embs = x[group_indices]   # (num_groups, 4, hidden_dim)
#
# File D:\PyCharmProjects\nyt-connections-solver\.venv\Lib\site-packages\torch\nn\modules\module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File D:\PyCharmProjects\nyt-connections-solver\.venv\Lib\site-packages\torch\nn\modules\module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# Cell In[16], line 30, in GraphEncoderLayer.forward(self, x, edge_index, edge_attr)
#      27 def forward(self, x, edge_index, edge_attr):
#      28     residual = x
# ---> 30     x = self.local_conv(x, edge_index, edge_attr)
#      32     x = x.unsqueeze(0)
#      33     x, _ = self.global_attn(x, x, x)
#
# File D:\PyCharmProjects\nyt-connections-solver\.venv\Lib\site-packages\torch\nn\modules\module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File D:\PyCharmProjects\nyt-connections-solver\.venv\Lib\site-packages\torch\nn\modules\module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File D:\PyCharmProjects\nyt-connections-solver\.venv\Lib\site-packages\torch_geometric\nn\conv\gatv2_conv.py:310, in GATv2Conv.forward(self, x, edge_index, edge_attr, return_attention_weights)
#     308     if x_r is not None:
#     309         num_nodes = min(num_nodes, x_r.size(0))
# --> 310     edge_index, edge_attr = remove_self_loops(
#     311         edge_index, edge_attr)
#     312     edge_index, edge_attr = add_self_loops(
#     313         edge_index, edge_attr, fill_value=self.fill_value,
#     314         num_nodes=num_nodes)
#     315 elif isinstance(edge_index, SparseTensor):
#
# File D:\PyCharmProjects\nyt-connections-solver\.venv\Lib\site-packages\torch_geometric\utils\loop.py:115, in remove_self_loops(edge_index, edge_attr)
#     112 mask = edge_index[0] != edge_index[1]
#     113 edge_index = edge_index[:, mask]
# --> 115 if not torch.jit.is_scripting() and isinstance(edge_index, EdgeIndex):
#     116     edge_index._is_undirected = is_undirected
#     118 if layout is not None:
#
# File D:\PyCharmProjects\nyt-connections-solver\.venv\Lib\site-packages\torch\_jit_internal.py:103, in is_scripting()
#      99 for i in range(2, 7):
#     100     globals()[f"BroadcastingList{i}"] = BroadcastingList1
# --> 103 def is_scripting() -> bool:
#     104     r"""
#     105     Function that returns True when in compilation and False otherwise. This
#     106     is useful especially with the @unused decorator to leave code in your
#    (...)    120                 return unsupported_linear_op(x)
#     121     """
#     122     return False
#
# KeyboardInterrupt:
